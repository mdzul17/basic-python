# %% [markdown]
# IF (Percabangan)

# %%
    kelerengku = 10
    if kelerengku:
       print ("Cetak ini jika benar", kelerengku)
# Out:
# Cetak ini jika benar 10

# %%
    tinggi_badan = int(input("Masukkan tinggi badan Anda : "))
    if tinggi_badan>=160:
       print ("Silakan, Anda boleh masuk")
    else:
       print ("Maaf, Anda belum boleh masuk")
# Out:
# Masukkan tinggi badan Anda : 155
# Maaf, Anda belum boleh masuk

# %%
    nilai = int(input("Masukkan nilai tugas Anda : "))
    if nilai>80:
       print("Selamat! Anda mendapat nilai A")
       print("Pertahankan!")
    elif nilai>70:
       print("Hore! Anda mendapat nilai B")
       print("Tingkatkan!")
    elif nilai>60:
       print("Hmm.. Anda mendapat nilai C")
       print("Ayo semangat!")
    else:
       print("Waduh, Anda mendapat nilai D")
       print("Yuk belajar lebih giat lagi!")
# Out:
# Masukkan nilai tugas Anda : 54
# Waduh, Anda mendapat nilai D
# Yuk belajar lebih giat lagi!

# %% [markdown]
# Perulangan (For dan While)

# %%
    for huruf in 'Dicoding':  # Contoh pertama
        print('Huruf: {}'.format(huruf))
     
    flowers = ['mawar', 'melati', 'anggrek']
    for flower in flowers:  # Contoh kedua
        print('Flower: {}'.format(flower))
# Out:
# Huruf: D
# Huruf: i
# Huruf: c
# Huruf: o
# Huruf: d
# Huruf: i
# Huruf: n
# Huruf: g
# Flower: mawar
# Flower: melati
# Flower: anggrek

# %%
    flowers = ['mawar', 'melati', 'anggrek']
    for index in range(len(flowers)):
        print('Flowers: {}'.format(flowers[index]))
# Out:
# Flowers: mawar
# Flowers: melati
# Flowers: anggrek

# %%
    for i in range(0, 6):
        for j in range(0, 6 - i):
            print('*', end='')
        print()

    i = 0
    j = 0 - sebelum 6
    ******

    i = 1
    j = 0 - sebelum 5
    *****

    i = 2
    j = 0 - sebelum 4
# Out:
# ******
# *****
# ****
# ***
# **
# *

# %% [markdown]
# Memasukkan array melalui input

# %%
cars = ["Ford", "Volvo", "BMW"]

mobil_input = input('Masukkan merk mobil ')
cars.append(mobil_input)

print(cars)
# Out:
# Masukkan merk mobil Toyota
# ['Ford', 'Volvo', 'BMW', 'Toyota']

# %% [markdown]
# Buat Array terdiri dari 10 nama mahasiswa, yang 3 nama mahasiswanya sudah dibuat. Maka perlu ada 7 tambahan nama mahasiswa, lalu tampilkan.

# %%
mobil_input = input('Masukkan merk mobil ')
cars.append(mobil_input)
print(cars)
# Out:
# Masukkan merk mobil Mercedes
# ['Ford', 'Volvo', 'BMW', 'Toyota', 'Mercedes']

# %% [markdown]
# w3schools.com
